# %%
import pandas as pd
import numpy as np

# %%
sismos = pd.read_csv('datos\\SSNMX_catalogo.csv', skiprows=4, skipfooter=7, engine='python')
# sismos[sismos['Magnitud']!='no calculable']
sismos['Magnitud']
# Out:
# 0       no calculable
# 1       no calculable
# 2       no calculable
# 3       no calculable
# 4       no calculable
#             ...
# 2166    no calculable
# 2167    no calculable
# 2168    no calculable
# 2169    no calculable
# 2170    no calculable
# Name: Magnitud, Length: 2171, dtype: object

# %%
df = pd.DataFrame({'ID':[302,401,302], 'name':['ivan', 'daniel', 'ivan']})
display(df)
df.duplicated()
# Out:
#     ID    name
# 0  302    ivan
# 1  401  daniel
# 2  302    ivan
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
movies = pd.read_csv('datos\\movies_metadata.csv')
movies.head()
# Out:
# C:\Users\109149\AppData\Local\Temp\ipykernel_4524\3050338582.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('datos\\movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
movies['video']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: video, Length: 45466, dtype: object

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# try to find duplicates
# normalizar los textos

# %%
movies = pd.read_csv('datos\\movies_metadata.csv')
movies.head()
movies.duplicated().sum()
# Out:
# C:\Users\109149\AppData\Local\Temp\ipykernel_16524\2048173854.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('datos\\movies_metadata.csv')
# np.int64(13)

# %%
movies[movies.duplicated(keep=False)].head()
# Out:
#       adult belongs_to_collection budget  \
# 676   False                   NaN      0
# 1465  False                   NaN      0
# 7345  False                   NaN      0
# 8068  False                   NaN      0
# 9165  False                   NaN      0
#
#                                                  genres homepage      id  \
# 676   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  105045
# 1465  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  105045
# 7345  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN    5511
# 8068  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...      NaN   23305
# 9165  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN    5511
#
#         imdb_id original_language   original_title  \
# 676   tt0111613                de  Das Versprechen
# 1465  tt0111613                de  Das Versprechen
# 7345  tt0062229                fr      Le Samouraï
# 8068  tt0295682                en      The Warrior
# ...

# %%
movies[movies['title']=='Blackout']
# Out:
#        adult belongs_to_collection budget  \
# 13261  False                   NaN      0
# 13375  False                   NaN      0
# 16764  False                   NaN      0
# 22682  False                   NaN      0
# 23567  False                   NaN      0
# 29737  False                   NaN      0
# 43820  False                   NaN      0
#
#                                                   genres  \
# 13261  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 13375  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 16764  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 22682  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 23567  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 29737                      [{'id': 18, 'name': 'Drama'}]
# 43820                [{'id': 99, 'name': 'Documentary'}]
#
#                                                 homepage      id    imdb_id  \
# 13261                                                NaN  141971  tt1180333
# ...

# %%
movies.drop_duplicates(inplace=True)
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
movies[movies.duplicated(subset='id', keep=False)]
movies[movies['title']=='Wife']
# Out:
#        adult belongs_to_collection budget                         genres  \
# 838    False                   NaN      0  [{'id': 18, 'name': 'Drama'}]
# 30001  False                   NaN      0  [{'id': 18, 'name': 'Drama'}]
#
#       homepage      id    imdb_id original_language original_title  \
# 838        NaN  132641  tt0046468                ja          Tsuma
# 30001      NaN  132641  tt0046468                ja          Tsuma
#
#                                                 overview  ... release_date  \
# 838    Ten years into a marriage, the wife is disappo...  ...   1953-04-29
# 30001  Ten years into a marriage, the wife is disappo...  ...   1953-04-29
#
#       revenue runtime                      spoken_languages    status  \
# 838       0.0    89.0  [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 30001     0.0    89.0  [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
#
#        tagline  title  video vote_average vote_count
# ...

# %%
movies = pd.read_csv('datos\\movies_metadata.csv')
movies.drop_duplicates(inplace=True)
movies.duplicated(subset='id', keep=False).sum()
# Out:
# C:\Users\109149\AppData\Local\Temp\ipykernel_16524\1093712412.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('datos\\movies_metadata.csv')
# np.int64(34)

# %%
movies = pd.read_csv('datos\\movies_metadata.csv')
movies.drop_duplicates(inplace=True)
# movies[movies.duplicated(subset='id', keep=False)].sort_values(by='id')
# normalizar titulos, overview, tagline, fecha 
movies = movies[movies.duplicated(subset='id')]

movies[movies.duplicated(subset='overview')]
# Out:
# C:\Users\109149\AppData\Local\Temp\ipykernel_16524\3666953477.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('datos\\movies_metadata.csv')
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
movies[movies.duplicated(subset='id', keep=False)]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# id mismo, todo lo mismo, pero popularity no
